# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "city": ["Москва", "Санкт-Петербург", "Казань", "Новосибирск"],
    "population": [15git status, 5.6, 1.3, 1.6],
    "growth": [0.8, 0.2, 1.1, 0.5]
})

print("Описательная статистика:")
print(df.describe())
print(f"\n Средняя численность: {df['population'].mean():.1f} млн")
print(f"Город с максимальным ростом: {df.loc[df['growth'].idxmax(), 'city']}")
# Out:
# Описательная статистика:
#        population    growth
# count    4.000000  4.000000
# mean     5.875000  0.650000
# std      6.391335  0.387298
# min      1.300000  0.200000
# 25%      1.525000  0.425000
# 50%      3.600000  0.650000
# 75%      7.950000  0.875000
# max     15.000000  1.100000
#
#  Средняя численность: 5.9 млн
# Город с максимальным ростом: Казань
